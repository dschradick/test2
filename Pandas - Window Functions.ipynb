# %%
#### Notizen
# https://mode.com/blog/bridge-the-gap-window-functions
# ttps://pandas.pydata.org/pandas-docs/stable/getting_started/comparison/comparison_with_sql.html

## + Pandas + Spark-SQL
# https://medium.com/jbennetcodes/how-to-get-rid-of-loops-and-use-window-functions-in-pandas-or-spark-sql-907f274850e4
# + SQL <-> Pandas: https://medium.com/jbennetcodes/how-to-rewrite-your-sql-queries-in-pandas-and-more-149d341fc53e

# %%
import pandas as pd
import numpy as np
df = pd.DataFrame({'group':['A','A','A','B','B','B'],
                   'value':[1,2,3,4,5,6]})

mtcars = pd.read_csv('~/Documents/Data/mtcars.csv',index_col='name')
mtcars.head(1)
# Out:
#             mpg  cyl   disp   hp  drat    wt   qsec  vs  am  gear  carb  \
# name
# Mazda RX4  21.0    6  160.0  110   3.9  2.62  16.46   0   1     4     4
#
#           car_type  hp_cumsum
# name
# Mazda RX4      suv        215

# %% [markdown]
# # Group by vs window function

# %%
df
# Out:
#   group  value
# 0     A      1
# 1     A      2
# 2     A      3
# 3     B      4
# 4     B      5
# 5     B      6

# %% [markdown]
# ## Group by

# %%
df.groupby('group').mean()
# Out:
#        value
# group
# A          2
# B          5

# %% [markdown]
# ## Window function

# %%
# AVG(value) OVER (PARTITION BY group)
# transform() methode für within group aggregation
# => analog zu "OVER(partition by ...)" in SQL:
# => apply get in vielen fällen auch
df1 = df.groupby('group')['value'].apply(np.cumsum)
df2 = df.groupby('group')['value'].transform(np.cumsum)
df3 = df.groupby('group')['value'].cumsum()
print(df1,df2,df3)
# Out:
# 0     1
# 1     3
# 2     6
# 3     4
# 4     9
# 5    15
# Name: value, dtype: int64 0     1
# 1     3
# 2     6
# 3     4
# 4     9
# 5    15
# Name: value, dtype: int64 0     1
# 1     3
# 2     6
# 3     4
# 4     9
# 5    15
# Name: value, dtype: int64

# %% [markdown]
# ..dasselbe..

# %%
x = np.arange(1,100)
pd.Series(x).rolling(3,min_periods=1).mean().head()
# Out:
# 0    1.0
# 1    1.5
# 2    2.0
# 3    3.0
# 4    4.0
# dtype: float64

# %% [markdown]
# # Cumsum

# %%
#SELECT sum(hp) OVER (PARTITION BY cyl ORDER BY hp )

# %%
mtcars['hp_cumsum'] = (mtcars.sort_values('hp')
                             .groupby('cyl')
                             ['hp']
                             .cumsum());  
mtcars[['cyl','hp','hp_cumsum']].sort_values(['cyl','hp_cumsum']).head(5)
# Out:
#                 cyl  hp  hp_cumsum
# name
# Honda Civic       4  52         52
# Merc 240D         4  62        114
# Toyota Corolla    4  65        179
# Fiat X1-9         4  66        245
# Fiat 128          4  66        311

# %% [markdown]
# # Rank

# %%
# select rank() over (partition by cyl order by hp desc)
mtcars['hp_rank'] = (mtcars.sort_values('hp')
                             .groupby('cyl')['hp']
                             .rank(method='first', ascending=False));  
mtcars[['cyl','hp','hp_rank']].sort_values(['cyl','hp_rank']).head(5)
# Out:
#                cyl   hp  hp_rank
# name
# Lotus Europa     4  113      1.0
# Volvo 142E       4  109      2.0
# Toyota Corona    4   97      3.0
# Merc 230         4   95      4.0
# Datsun 710       4   93      5.0

# %%
# SELECT sum(hp) OVER (PARTITION BY cyl ORDER BY hp rows between 2 preceding and current)

mtcars['hp_cumsum'] = (mtcars.sort_values('hp')
                             .groupby('cyl')
                             ['hp']
                             .apply(lambda x : x.rolling(3).sum()));  
mtcars[['cyl','hp','hp_cumsum']].sort_values(['cyl','hp_cumsum']).head(5)
# Out:
#                 cyl  hp  hp_cumsum
# name
# Toyota Corolla    4  65      179.0
# Fiat X1-9         4  66      193.0
# Fiat 128          4  66      197.0
# Porsche 914-2     4  91      223.0
# Datsun 710        4  93      250.0

# %%
# Differenz zwischen den Werten
mtcars['diff_hp_in_cyl'] = (mtcars
                            .sort_values('hp')
                            .groupby('cyl')
                            ['hp']
                            .apply(
                                lambda x : x - x.shift())
                            .fillna(-1))

# mean für jede gruppe
(mtcars.sort_values('hp')
    .groupby('cyl')
    ['hp'].apply(lambda x : np.mean((x - x.shift()))))
# Out:
# cyl
# 4     6.100000
# 6    11.666667
# 8    14.230769
# Name: hp, dtype: float64

# %%
# Komplexe Transformationen von Gruppen
def top_n(df,n=5):
    df['hp_cyl_mean'] = df.hp.mean()
    return df.head(n)

mtcars.groupby('cyl',group_keys=False).apply(top_n,2)
# Out:
#                     mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# name
# Datsun 710         22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# Merc 240D          24.4    4  146.7   62  3.69  3.190  20.00   1   0     4
# Mazda RX4          21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# Mazda RX4 Wag      21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
# Duster 360         14.3    8  360.0  245  3.21  3.570  15.84   0   0     3
#
#                    carb car_type  hp_cumsum  hp_rank  diff_hp_in_cyl  \
# name
# Datsun 710            1      suv      250.0      5.0             2.0
# Merc 240D             2      suv        NaN     10.0            10.0
# Mazda RX4             4      suv        NaN      4.0             5.0
# Mazda RX4 Wag         4      suv      325.0      5.0             0.0
# Hornet Sportabout     2    smart      500.0     12.0             0.0
# Duster 360            4    smart      720.0      4.0             0.0
#
#                    hp_cyl_mean
# name
# Datsun 710           82.636364
# Merc 240D            82.636364
# Mazda RX4           122.285714
# Mazda RX4 Wag       122.285714
# Hornet Sportabout   209.214286
# Duster 360          209.214286

# %%
mtcars.groupby('cyl').apply(np.mean) # => fasst zusammen
mtcars.groupby('cyl').apply(lambda x: x.rank(ascending=False)) # hier nicht
# Out:
#                       mpg  cyl  disp    hp  drat    wt  qsec    vs    am  \
# name
# Mazda RX4             2.5  4.0   5.5   5.0   3.5   7.0   6.0   6.0   2.0
# Mazda RX4 Wag         2.5  4.0   5.5   5.0   3.5   5.0   5.0   6.0   2.0
# Datsun 710            8.5  6.0   6.0   5.0   8.0   5.0   7.0   5.5   4.5
# Hornet 4 Drive        1.0  4.0   1.0   5.0   6.0   4.0   2.0   2.5   5.5
# Hornet Sportabout     2.0  7.5   5.5  11.5   6.5  12.0   9.0   7.5   8.5
# Valiant               6.0  4.0   2.0   7.0   7.0   1.0   1.0   2.5   5.5
# Duster 360           11.0  7.5   5.5   3.5   5.0   9.5  11.0   7.5   8.5
# Merc 240D             7.0  6.0   1.0  10.0  11.0   1.0   3.0   5.5  10.0
# Merc 230              8.5  6.0   2.0   4.0   7.0   2.0   1.0   5.5  10.0
# Merc 280              5.0  4.0   3.5   2.5   1.5   2.5   4.0   2.5   5.5
# Merc 280C             7.0  4.0   3.5   2.5   1.5   2.5   3.0   2.5   5.5
# Merc 450SE            4.0  7.5  13.0   9.0  10.0   4.0   6.0   7.5   8.5
# Merc 450SL            3.0  7.5  13.0   9.0  10.0   8.0   4.0   7.5   8.5
# Merc 450SLC           7.5  7.5  13.0   9.0  10.0   7.0   1.0   7.5   8.5
# Cadillac Fleetwood   13.5  7.5   1.0   7.0  13.0   3.0   2.0   7.5   8.5
# Lincoln Continental  13.5  7.5   2.0   6.0  12.0   1.0   3.0   7.5   8.5
# Chrysler Imperial    10.0  7.5   3.0   5.0   4.0   2.0   5.0   7.5   8.5
# Fiat 128              2.0  6.0   9.0   7.5   5.5   6.0   5.0   5.5   4.5
# Honda Civic           3.5  6.0  10.0  11.0   1.0  10.0   9.0   5.5   4.5
# Toyota Corolla        1.0  6.0  11.0   9.0   3.0   9.0   4.0   5.5   4.5
# Toyota Corona        10.0  6.0   5.0   3.0  10.0   4.0   2.0   5.5  10.0
# Dodge Challenger      6.0  7.5   9.0  13.5  14.0  11.0  10.0   7.5   8.5
# AMC Javelin           7.5  7.5  10.0  13.5   6.5  13.0   7.0   7.5   8.5
# Camaro Z28           12.0  7.5   8.0   3.5   2.0   6.0  12.0   7.5   8.5
# Pontiac Firebird      1.0  7.5   4.0  11.5   8.0   5.0   8.0   7.5   8.5
# Fiat X1-9             5.0  6.0   8.0   7.5   5.5   8.0   6.0   5.5   4.5
# Porsche 914-2         6.0  6.0   4.0   6.0   2.0   7.0  11.0  11.0   4.5
# Lotus Europa          3.5  6.0   7.0   1.0   9.0  11.0  10.0   5.5   4.5
# Ford Pantera L        5.0  7.5   7.0   2.0   1.0  14.0  14.0   7.5   1.5
# Ferrari Dino          4.0  4.0   7.0   1.0   5.0   6.0   7.0   6.0   2.0
# Maserati Bora         9.0  7.5  11.0   1.0   3.0   9.5  13.0   7.5   1.5
# Volvo 142E           11.0  6.0   3.0   2.0   4.0   3.0   8.0   5.5   4.5
#
#                      gear  carb  car_type  hp_cumsum  hp_rank  diff_hp_in_cyl
# name
# Mazda RX4             3.5   3.5       2.0        NaN      4.0             3.0
# Mazda RX4 Wag         3.5   3.5       2.0        5.0      3.0             5.0
# Datsun 710            6.5   9.0       6.0        5.0      7.0             7.0
# Hornet 4 Drive        6.5   6.5       2.0        4.0      2.0             5.0
# Hornet Sportabout     8.5  12.5       7.5       11.0      3.0            11.0
# Valiant               6.5   6.5       5.5        NaN      1.0             7.0
# Duster 360            8.5   4.5       7.5        3.0     11.0            11.0
# Merc 240D             6.5   3.5       6.0        NaN      2.0             3.0
# Merc 230              6.5   3.5       6.0        4.0      8.0             7.0
# Merc 280              3.5   3.5       5.5        2.0      5.0             5.0
# Merc 280C             3.5   3.5       5.5        3.0      6.0             2.0
# Merc 450SE            8.5   9.0       7.5        8.0      5.0            11.0
# Merc 450SL            8.5   9.0       7.5       10.0      7.0             8.0
# Merc 450SLC           8.5   9.0       7.5        9.0      6.0            11.0
# Cadillac Fleetwood    8.5   4.5       7.5        7.0      8.0             2.5
# Lincoln Continental   8.5   4.5       7.5        6.0      9.0             7.0
# Chrysler Imperial     8.5   4.5       7.5        5.0     10.0             5.5
# Fiat 128              6.5   9.0       6.0        7.0      4.0            10.0
# Honda Civic           6.5   3.5       6.0        NaN      1.0            11.0
# Toyota Corolla        6.5   9.0       6.0        9.0      3.0             5.0
# Toyota Corona        11.0   9.0       6.0        3.0      9.0             7.0
# Dodge Challenger      8.5  12.5       7.5        NaN      2.0            14.0
# AMC Javelin           8.5  12.5       7.5        NaN      1.0            11.0
# Camaro Z28            8.5   4.5       7.5        4.0     12.0             5.5
# Pontiac Firebird      8.5  12.5       7.5       12.0      4.0             2.5
# Fiat X1-9             6.5   9.0       6.0        8.0      5.0             9.0
# Porsche 914-2         1.5   3.5       6.0        6.0      6.0             1.0
# Lotus Europa          1.5   3.5       6.0        1.0     11.0             4.0
# Ford Pantera L        1.5   4.5       7.5        2.0     13.0             4.0
# Ferrari Dino          1.0   1.0       5.5        1.0      7.0             1.0
# Maserati Bora         1.5   1.0       7.5        1.0     14.0             1.0
# Volvo 142E            6.5   3.5       6.0        2.0     10.0             2.0

# %%
mtcars.groupby('cyl').transform(np.mean)
# Out:
#                            mpg        disp          hp      drat        wt  \
# name
# Mazda RX4            19.742857  183.314286  122.285714  3.585714  3.117143
# Mazda RX4 Wag        19.742857  183.314286  122.285714  3.585714  3.117143
# Datsun 710           26.663636  105.136364   82.636364  4.070909  2.285727
# Hornet 4 Drive       19.742857  183.314286  122.285714  3.585714  3.117143
# Hornet Sportabout    15.100000  353.100000  209.214286  3.229286  3.999214
# Valiant              19.742857  183.314286  122.285714  3.585714  3.117143
# Duster 360           15.100000  353.100000  209.214286  3.229286  3.999214
# Merc 240D            26.663636  105.136364   82.636364  4.070909  2.285727
# Merc 230             26.663636  105.136364   82.636364  4.070909  2.285727
# Merc 280             19.742857  183.314286  122.285714  3.585714  3.117143
# Merc 280C            19.742857  183.314286  122.285714  3.585714  3.117143
# Merc 450SE           15.100000  353.100000  209.214286  3.229286  3.999214
# Merc 450SL           15.100000  353.100000  209.214286  3.229286  3.999214
# Merc 450SLC          15.100000  353.100000  209.214286  3.229286  3.999214
# Cadillac Fleetwood   15.100000  353.100000  209.214286  3.229286  3.999214
# Lincoln Continental  15.100000  353.100000  209.214286  3.229286  3.999214
# Chrysler Imperial    15.100000  353.100000  209.214286  3.229286  3.999214
# Fiat 128             26.663636  105.136364   82.636364  4.070909  2.285727
# Honda Civic          26.663636  105.136364   82.636364  4.070909  2.285727
# Toyota Corolla       26.663636  105.136364   82.636364  4.070909  2.285727
# Toyota Corona        26.663636  105.136364   82.636364  4.070909  2.285727
# Dodge Challenger     15.100000  353.100000  209.214286  3.229286  3.999214
# AMC Javelin          15.100000  353.100000  209.214286  3.229286  3.999214
# Camaro Z28           15.100000  353.100000  209.214286  3.229286  3.999214
# Pontiac Firebird     15.100000  353.100000  209.214286  3.229286  3.999214
# Fiat X1-9            26.663636  105.136364   82.636364  4.070909  2.285727
# Porsche 914-2        26.663636  105.136364   82.636364  4.070909  2.285727
# Lotus Europa         26.663636  105.136364   82.636364  4.070909  2.285727
# Ford Pantera L       15.100000  353.100000  209.214286  3.229286  3.999214
# Ferrari Dino         19.742857  183.314286  122.285714  3.585714  3.117143
# Maserati Bora        15.100000  353.100000  209.214286  3.229286  3.999214
# Volvo 142E           26.663636  105.136364   82.636364  4.070909  2.285727
#
#                           qsec        vs        am      gear      carb  \
# name
# Mazda RX4            17.977143  0.571429  0.428571  3.857143  3.428571
# Mazda RX4 Wag        17.977143  0.571429  0.428571  3.857143  3.428571
# Datsun 710           19.137273  0.909091  0.727273  4.090909  1.545455
# Hornet 4 Drive       17.977143  0.571429  0.428571  3.857143  3.428571
# Hornet Sportabout    16.772143  0.000000  0.142857  3.285714  3.500000
# Valiant              17.977143  0.571429  0.428571  3.857143  3.428571
# Duster 360           16.772143  0.000000  0.142857  3.285714  3.500000
# Merc 240D            19.137273  0.909091  0.727273  4.090909  1.545455
# Merc 230             19.137273  0.909091  0.727273  4.090909  1.545455
# Merc 280             17.977143  0.571429  0.428571  3.857143  3.428571
# Merc 280C            17.977143  0.571429  0.428571  3.857143  3.428571
# Merc 450SE           16.772143  0.000000  0.142857  3.285714  3.500000
# Merc 450SL           16.772143  0.000000  0.142857  3.285714  3.500000
# Merc 450SLC          16.772143  0.000000  0.142857  3.285714  3.500000
# Cadillac Fleetwood   16.772143  0.000000  0.142857  3.285714  3.500000
# Lincoln Continental  16.772143  0.000000  0.142857  3.285714  3.500000
# Chrysler Imperial    16.772143  0.000000  0.142857  3.285714  3.500000
# Fiat 128             19.137273  0.909091  0.727273  4.090909  1.545455
# Honda Civic          19.137273  0.909091  0.727273  4.090909  1.545455
# Toyota Corolla       19.137273  0.909091  0.727273  4.090909  1.545455
# Toyota Corona        19.137273  0.909091  0.727273  4.090909  1.545455
# Dodge Challenger     16.772143  0.000000  0.142857  3.285714  3.500000
# AMC Javelin          16.772143  0.000000  0.142857  3.285714  3.500000
# Camaro Z28           16.772143  0.000000  0.142857  3.285714  3.500000
# Pontiac Firebird     16.772143  0.000000  0.142857  3.285714  3.500000
# Fiat X1-9            19.137273  0.909091  0.727273  4.090909  1.545455
# Porsche 914-2        19.137273  0.909091  0.727273  4.090909  1.545455
# Lotus Europa         19.137273  0.909091  0.727273  4.090909  1.545455
# Ford Pantera L       16.772143  0.000000  0.142857  3.285714  3.500000
# Ferrari Dino         17.977143  0.571429  0.428571  3.857143  3.428571
# Maserati Bora        16.772143  0.000000  0.142857  3.285714  3.500000
# Volvo 142E           19.137273  0.909091  0.727273  4.090909  1.545455
#
#                       hp_cumsum  hp_rank  diff_hp_in_cyl
# name
# Mazda RX4            355.000000      4.0        9.857143
# Mazda RX4 Wag        355.000000      4.0        9.857143
# Datsun 710           247.333333      6.0        5.454545
# Hornet 4 Drive       355.000000      4.0        9.857143
# Hornet Sportabout    616.916667      7.5       13.142857
# Valiant              355.000000      4.0        9.857143
# Duster 360           616.916667      7.5       13.142857
# Merc 240D            247.333333      6.0        5.454545
# Merc 230             247.333333      6.0        5.454545
# Merc 280             355.000000      4.0        9.857143
# Merc 280C            355.000000      4.0        9.857143
# Merc 450SE           616.916667      7.5       13.142857
# Merc 450SL           616.916667      7.5       13.142857
# Merc 450SLC          616.916667      7.5       13.142857
# Cadillac Fleetwood   616.916667      7.5       13.142857
# Lincoln Continental  616.916667      7.5       13.142857
# Chrysler Imperial    616.916667      7.5       13.142857
# Fiat 128             247.333333      6.0        5.454545
# Honda Civic          247.333333      6.0        5.454545
# Toyota Corolla       247.333333      6.0        5.454545
# Toyota Corona        247.333333      6.0        5.454545
# Dodge Challenger     616.916667      7.5       13.142857
# AMC Javelin          616.916667      7.5       13.142857
# Camaro Z28           616.916667      7.5       13.142857
# Pontiac Firebird     616.916667      7.5       13.142857
# Fiat X1-9            247.333333      6.0        5.454545
# Porsche 914-2        247.333333      6.0        5.454545
# Lotus Europa         247.333333      6.0        5.454545
# Ford Pantera L       616.916667      7.5       13.142857
# Ferrari Dino         355.000000      4.0        9.857143
# Maserati Bora        616.916667      7.5       13.142857
# Volvo 142E           247.333333      6.0        5.454545

# %%
time_key = pd.TimeGrouper('5min')
# ...  .groupby(['key', time_key]).sum())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-1a1260d4f2e3> in <module>
# ----> 1 time_key = pd.TimeGrouper('5min')
#       2 # ...  .groupby(['key', time_key]).sum())
#
# /opt/conda/lib/python3.7/site-packages/pandas/__init__.py in __getattr__(name)
#     212
#     213             return Panel
# --> 214         raise AttributeError("module 'pandas' has no attribute '{}'".format(name))
#     215
#     216
#
# AttributeError: module 'pandas' has no attribute 'TimeGrouper'
